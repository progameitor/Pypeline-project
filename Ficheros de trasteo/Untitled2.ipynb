# %%
import pandas as pd

import os
print(os.getcwd())
df = pd.read_csv("Output/good_weatherr.csv")
df
# Out:
# /home/javier/Documents/Pypeline-project
#     Unnamed: 0  year  semester   day  month  Max Temp  Mean Temp  Min Temp  \
# 0            0  10.9       0.0  15.5    3.5      19.8       13.5       7.7
# 1            1  10.9       0.0  16.0    9.6      23.8       17.7      12.0
# 2            2  10.9       0.0  15.5    3.5      18.5       12.4       6.8
# 3            3  10.9       0.0  16.0    9.6      23.7       16.7      10.1
# 4            4  11.0       0.0  15.5    3.5      18.6       12.0       5.8
# 5            5  11.0       0.0  16.0    9.6      22.4       16.5      11.1
# 6            6  11.0       0.0   9.1    1.9      10.8        6.9       3.3
# 7            7  11.0       0.0  13.9    8.8      19.5       13.7       8.7
# 8            8  11.0       0.0  15.5    3.5      17.6       11.9       6.7
# 9            9  11.0       0.0  16.0    9.6      21.8       15.2       9.0
# 10          10  11.0       0.0  15.5    3.5      18.3       12.0       6.1
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'year', 'semester', 'day', 'month', 'Max Temp',
#        'Mean Temp', 'Min Temp', 'Max Hum', 'Mean Hum', 'Min Hum', 'Max Vis Km',
#        'Mean Vis Km', 'Min Vis Km', 'Max Wind Km/h', 'Mean Wind Kmh'],
#       dtype='object')

# %%
df =df.drop('Unnamed: 0',axis= 1)

# %%
df
# Out:
#     year  semester   day  month  Max Temp  Mean Temp  Min Temp  Max Hum  \
# 0   10.9       0.0  15.5    3.5      19.8       13.5       7.7     87.6
# 1   10.9       0.0  16.0    9.6      23.8       17.7      12.0     80.5
# 2   10.9       0.0  15.5    3.5      18.5       12.4       6.8     87.8
# 3   10.9       0.0  16.0    9.6      23.7       16.7      10.1     78.7
# 4   11.0       0.0  15.5    3.5      18.6       12.0       5.8     84.0
# 5   11.0       0.0  16.0    9.6      22.4       16.5      11.1     80.4
# 6   11.0       0.0   9.1    1.9      10.8        6.9       3.3     49.2
# 7   11.0       0.0  13.9    8.8      19.5       13.7       8.7     73.9
# 8   11.0       0.0  15.5    3.5      17.6       11.9       6.7     84.3
# 9   11.0       0.0  16.0    9.6      21.8       15.2       9.0     78.5
# 10  11.0       0.0  15.5    3.5      18.3       12.0       6.1     86.4
# 11  11.0       0.0  16.0    9.6      22.1       16.4      11.0     83.2
# ...

# %%
df2 = pd.read_csv("Output/poblacion.csv")
df2
# Out:
#     Unnamed: 0           Fecha  Poblacion
# 0           43      Junio 1997  5.220.731
# 1           42  Diciembre 1997  5.242.444
# 2           41      Junio 1998  5.262.869
# 3           40  Diciembre 1998  5.284.618
# 4           39      Junio 1999  5.305.592
# 5           38  Diciembre 1999  5.329.606
# 6           37      Junio 2000  5.353.391
# 7           36  Diciembre 2000  5.379.087
# 8           35      Junio 2001  5.404.959
# 9           34  Diciembre 2001  5.478.405
# 10          33      Junio 2002  5.561.622
# 11          32  Diciembre 2002  5.638.827
# 12          31      Junio 2003  5.708.433
# 13          30  Diciembre 2003  5.766.566
# 14          29      Junio 2004  5.807.962
# 15          28  Diciembre 2004  5.866.186
# 16          27      Junio 2005  5.912.335
# 17          26  Diciembre 2005  5.953.604
# 18          25      Junio 2006  6.003.925
# 19          24  Diciembre 2006  6.074.984
# 20          23      Junio 2007  6.152.759
# ...

# %%
df2 =df2.drop('Unnamed: 0',axis= 1)

# %%
df2
# Out:
#              Fecha  Poblacion
# 0       Junio 1997  5.220.731
# 1   Diciembre 1997  5.242.444
# 2       Junio 1998  5.262.869
# 3   Diciembre 1998  5.284.618
# 4       Junio 1999  5.305.592
# 5   Diciembre 1999  5.329.606
# 6       Junio 2000  5.353.391
# 7   Diciembre 2000  5.379.087
# 8       Junio 2001  5.404.959
# 9   Diciembre 2001  5.478.405
# 10      Junio 2002  5.561.622
# 11  Diciembre 2002  5.638.827
# 12      Junio 2003  5.708.433
# 13  Diciembre 2003  5.766.566
# 14      Junio 2004  5.807.962
# 15  Diciembre 2004  5.866.186
# 16      Junio 2005  5.912.335
# 17  Diciembre 2005  5.953.604
# 18      Junio 2006  6.003.925
# 19  Diciembre 2006  6.074.984
# 20      Junio 2007  6.152.759
# 21  Diciembre 2007  6.226.195
# 22      Junio 2008  6.283.747
# 23  Diciembre 2008  6.327.594
# 24      Junio 2009  6.354.091
# 25  Diciembre 2009  6.373.532
# 26      Junio 2010  6.384.358
# 27  Diciembre 2010  6.394.239
# 28      Junio 2011  6.409.093
# 29  Diciembre 2011  6.425.573
# ...

# %%
df2.dtypes
# Out:
# Fecha        object
# Poblacion    object
# dtype: object

# %%
df2["Fecha"]=df2.astype(str)

# %%
df2.dtypes
# Out:
# Fecha        object
# Poblacion    object
# dtype: object

# %%
df =df.join(df2)

# %%
df
# Out:
#     year  semester   day  month  Max Temp  Mean Temp  Min Temp  Max Hum  \
# 0   10.9       0.0  15.5    3.5      19.8       13.5       7.7     87.6
# 1   10.9       0.0  16.0    9.6      23.8       17.7      12.0     80.5
# 2   10.9       0.0  15.5    3.5      18.5       12.4       6.8     87.8
# 3   10.9       0.0  16.0    9.6      23.7       16.7      10.1     78.7
# 4   11.0       0.0  15.5    3.5      18.6       12.0       5.8     84.0
# 5   11.0       0.0  16.0    9.6      22.4       16.5      11.1     80.4
# 6   11.0       0.0   9.1    1.9      10.8        6.9       3.3     49.2
# 7   11.0       0.0  13.9    8.8      19.5       13.7       8.7     73.9
# 8   11.0       0.0  15.5    3.5      17.6       11.9       6.7     84.3
# 9   11.0       0.0  16.0    9.6      21.8       15.2       9.0     78.5
# 10  11.0       0.0  15.5    3.5      18.3       12.0       6.1     86.4
# 11  11.0       0.0  16.0    9.6      22.1       16.4      11.0     83.2
# ...

# %%
df = df.drop("year",axis = 1)
df = df.drop("semester",axis = 1)
df = df.drop("month",axis = 1)
df = df.drop("day",axis = 1)

# %%
df
# Out:
#     Max Temp  Mean Temp  Min Temp  Max Hum  Mean Hum  Min Hum  Max Vis Km  \
# 0       19.8       13.5       7.7     87.6      65.6     44.9         8.5
# 1       23.8       17.7      12.0     80.5      59.6     41.0         9.4
# 2       18.5       12.4       6.8     87.8      63.7     41.6         8.9
# 3       23.7       16.7      10.1     78.7      56.7     34.3         8.2
# 4       18.6       12.0       5.8     84.0      57.4     32.8         8.5
# 5       22.4       16.5      11.1     80.4      59.7     38.4         9.0
# 6       10.8        6.9       3.3     49.2      37.0     22.8         4.5
# 7       19.5       13.7       8.7     73.9      53.3     33.8         7.4
# 8       17.6       11.9       6.7     84.3      61.6     39.9         8.6
# 9       21.8       15.2       9.0     78.5      56.8     35.4         8.1
# 10      18.3       12.0       6.1     86.4      62.3     39.5         8.4
# 11      22.1       16.4      11.0     83.2      62.3     41.0         9.4
# ...

# %%
lista =['Fecha','Poblacion','Max Temp', 'Mean Temp', 'Min Temp', 'Max Hum', 'Mean Hum','Min Hum', 'Max Vis Km', 'Mean Vis Km', 'Min Vis Km', 'Max Wind Km/h','Mean Wind Kmh']
df =df[lista]
df
# Out:
#              Fecha  Poblacion  Max Temp  Mean Temp  Min Temp  Max Hum  \
# 0       Junio 1997  5.220.731      19.8       13.5       7.7     87.6
# 1   Diciembre 1997  5.242.444      23.8       17.7      12.0     80.5
# 2       Junio 1998  5.262.869      18.5       12.4       6.8     87.8
# 3   Diciembre 1998  5.284.618      23.7       16.7      10.1     78.7
# 4       Junio 1999  5.305.592      18.6       12.0       5.8     84.0
# 5   Diciembre 1999  5.329.606      22.4       16.5      11.1     80.4
# 6       Junio 2000  5.353.391      10.8        6.9       3.3     49.2
# 7   Diciembre 2000  5.379.087      19.5       13.7       8.7     73.9
# 8       Junio 2001  5.404.959      17.6       11.9       6.7     84.3
# 9   Diciembre 2001  5.478.405      21.8       15.2       9.0     78.5
# 10      Junio 2002  5.561.622      18.3       12.0       6.1     86.4
# 11  Diciembre 2002  5.638.827      22.1       16.4      11.0     83.2
# ...

# %%
df.to_csv("Output/resultado.csv")

# %%
lis =['Max Temp', 'Mean Temp', 'Min Temp']
df3=df[lis]
df3
# Out:
#     Max Temp  Mean Temp  Min Temp
# 0       19.8       13.5       7.7
# 1       23.8       17.7      12.0
# 2       18.5       12.4       6.8
# 3       23.7       16.7      10.1
# 4       18.6       12.0       5.8
# 5       22.4       16.5      11.1
# 6       10.8        6.9       3.3
# 7       19.5       13.7       8.7
# 8       17.6       11.9       6.7
# 9       21.8       15.2       9.0
# 10      18.3       12.0       6.1
# 11      22.1       16.4      11.0
# 12      18.6       12.6       6.9
# 13      22.7       16.7      11.2
# 14      15.3       10.3       5.6
# 15      23.5       16.8      10.5
# 16      19.3       12.3       5.9
# 17      23.1       16.6      10.4
# 18      19.0       12.5       6.6
# 19      23.9       17.5      11.8
# 20      17.2       11.5       6.1
# 21      22.7       15.6       8.8
# 22      18.6       12.4       6.6
# 23      22.1       15.7       9.6
# 24      19.1       12.4       6.3
# 25      24.2       17.8      11.7
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

sns.lineplot(data=df3)
